# %%
# PART OF THIS CODE IS FROM MICHAEL MURPHY - THANKS!
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from collections import OrderedDict
import glob
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os, sys
import glob, re
import seaborn as sns
pd.set_option('display.max_rows', 500) 
pd.set_option('display.max_columns', 100)

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, StratifiedKFold, cross_val_score, train_test_split
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.utils.multiclass import type_of_target # used to check the Y labels are appropriate for classification
from sklearn.metrics import roc_curve
from sklearn import metrics
from sklearn.utils import shuffle
from scipy import interp
from scipy.stats import mannwhitneyu
from scipy.stats import kruskal
from statsmodels.stats.multitest import multipletests
from sklearn.cross_decomposition import PLSRegression
from sklearn.preprocessing import normalize
from sklearn.preprocessing import minmax_scale


def get_num_labels(ds):
    ds['labels'] = ds['labels']*1
    vals = ds['labels'].values
    try:
        vals = [item for sublist in vals for item in sublist]
    except:
        pass
    labels = set(vals)
    ds['num_labels'] = len(labels)
    ds['label_set'] = labels
    return ds

def check_pre_norm(ds):
    if ds['data_set'] in pre_norm_ds:
        ds['pre_norm'] = 'Yes'
    else:
        ds['pre_norm'] = 'No'
    return ds

def convert_nan_to_val(data, value=0):
    data[pd.isnull(data)] = value
    return data

# %%
#### Use this if DOING a fresh modeling fitting analysis
bn = True # use the percentile normalized data or no? 
log = False
stand_scaler = False
reanalysis = True
model = 'plsda' #log_reg, rf or svm

if reanalysis:
    pre_norm_ds = [ 'plasmaall_author',
                    'urineall_author',
                    'm_oxylipin_chronic_hep_b',
                    'm_chronic_hep_b_POS',
                    'm_chronic_hep_b_NEG',
                    'm_CER_mass_spectrometry_v4',
                    'm_CER_mass_spectrometry_v4_3_CS',
                    'm_CER_mass_spectrometry_v4_0_NS',
                    'm_CER_mass_spectrometry_v4_2_FS',
                    'm_CER_mass_spectrometry_v4_1_COPD',
                    'm_EICO_mass_spectrometry_v4',
                    'm_EICO_mass_spectrometry_v4_3_CS',
                    'm_EICO_mass_spectrometry_v4_0_NS',
                    'm_EICO_mass_spectrometry_v4_2_FS',
                    'm_EICO_mass_spectrometry_v4_1_COPD',
                    'AN000580',
                    'AN000581',
                    'AN001503',
                    'ulsam_author']

    if bn:
        path = './bn_pickles/*.pkl'
    else:
        path = './pickles/*.pkl'

    datasets = OrderedDict()
    for fn in sorted(glob.glob(path)):
        data = pd.read_pickle(open(fn,'rb'))
        datasets[data[0]['study']] = data
    
else:
    #### Use this if NOT doing a fresh modeling fitting analysis
    pickle_file = './YES_bn_ds_models_and_sigfeat_NO_log_NO_standscal_NO_multi_mapped_labels.pkl'
    ### The non-batch corrected pickle for the dataset
    # pickle_file = './NO_bn_dataset_models_and_sigfeat_YES_log.pkl'
    datasets = pickle.load(open(pickle_file, 'rb'))

# %%
def train_model(X,y,ds,model):
    X,y = shuffle(X,y)
    if model == 'log_reg':
        if ds['num_labels'] != 2:
            clf = LogisticRegressionCV(scoring='accuracy', penalty='l1', solver='liblinear', tol=1e-4, intercept_scaling=1, max_iter=500, multi_class='ovr')
        else:
            clf = LogisticRegressionCV(scoring='roc_auc', penalty='l1', solver='liblinear', tol=1e-4, intercept_scaling=1, max_iter=500)
    elif model == 'rf':
        param_grid = {'n_estimators':[100,500,1000]}
        clf = GridSearchCV(RandomForestClassifier(n_estimators=1000, n_jobs=-1), param_grid, cv=3, n_jobs=-1)
    elif model == 'svm':
        param_grid = {'gamma': [1e-3, 0.01, 0.1, 1], 'C': [0.01, 0.1, 1, 10, 100]}
        clf = GridSearchCV(SVC(kernel='linear', probability=True), param_grid, cv=3, n_jobs=-1)
    elif model == 'plsda':
        param_grid = {'n_components': [2]}
        clf = GridSearchCV(PLSRegression(), param_grid, cv=3, n_jobs=-1)
    else:
        print('no valid classifier input, please try again with one of: log_reg, rf or svm')
        exit(0)
    cv = StratifiedKFold(n_splits=5, shuffle=True) # so this will probably give rather high - at the end you just get the last model...
    aucs = []
    num_stat = []
    for train, test in cv.split(X,y):
        x_train, y_train = X[train], y[train]
        x_test, y_test = X[test], y[test]
#         print('train, test pre: ',x_train.shape, x_test.shape)
        ###### i guess here you can find the sig features using the train data, and mask the x_train / then x_test 
        p = np.zeros(x_train.shape[1]) + np.nan
        for i in range(x_train.shape[1]):
            feat_data = []
            for j in set(y_train):
                try:
                    X_0 = x_train[y_train==j,i]
                    X_0 = X_0[~np.isnan(X_0)]
                    feat_data.append(X_0)
                except:
                    pass 
            if set(feat_data[0]) == set(feat_data[1]):
                p[i] = 1
                continue
            else:
                _, p[i] = mannwhitneyu(feat_data[0],feat_data[1], alternative='two-sided')                     
        try:
            _, p[~np.isnan(p)], _, _ = multipletests(p[~np.isnan(p)], alpha=0.05, method='fdr_bh')
        except:
            pass
        
        # massage the y valeus into the format for pls-da
#         y_test_new = np.zeros((y_test.shape[0],2))
#         y_test_new[np.arange(y_test.shape[0]), y_test] = 1
        y_train_new = np.zeros((y_train.shape[0],2))
        y_train_new[np.arange(y_train.shape[0]), y_train] = 1
        
        x_train = x_train[:,p<0.05]
        x_test = x_test[:,p<0.05]
        num_stat.append(x_train.shape[1])
        if x_train.shape[1] == 0:
            return 0.5, 0, ',', y_train.shape, y_test.shape, 0, np.asarray(num_stat).mean()
        if x_test.shape[1] == 0:
            return 0.5, 0, ',', y_train.shape, y_test.shape, 0, np.asarray(num_stat).mean()
        if x_train.shape[1] < 3:
            return 0.5, 0, ',', y_train.shape, y_test.shape, 0, np.asarray(num_stat).mean()
        if x_test.shape[1] < 3:
            return 0.5, 0, ',', y_train.shape, y_test.shape, 0, np.asarray(num_stat).mean()
        if stand_scaler:
            scaler = StandardScaler()
            x_train = scaler.fit_transform(x_train)
            x_test = scaler.transform(x_test)
        clf.fit(x_train, y_train_new)
        y_pred = clf.predict(x_test)
        y_pred = np.absolute(y_pred)
        row_sum = np.repeat(y_pred.sum(axis=1),2).reshape((-1,2))
        y_pred = np.divide(y_pred, row_sum)
        fpr, tpr, _ = roc_curve(y_test, y_pred[:,1])
        auc_value = metrics.auc(fpr, tpr)
        aucs.append(auc_value) 
    auc = np.asarray(aucs)
    if ds['num_labels'] != 2:
        multi_aucs = auc
    else: multi_aucs = 0
    return auc.mean(), auc.std(), clf, y_train.shape, y_test.shape, multi_aucs, np.asarray(num_stat).mean()

def fit_model(X,y,ds,model):
    mean, std, clf, train_size, test_size, multi_aucs, num_stat =  train_model(X,y,ds,model)
    if mean == 1.0 or mean == 0.5:
        mean, std, clf, train_size, test_size, multi_aucs, num_stat = train_model(X,y,ds,model)
    return mean, std, train_size[0], test_size[0], clf, multi_aucs, num_stat

# %%
# Used to fit models for all the datasets!
for k, v in datasets.items():  
    for ds in v:     
        print(k, ds['data_set'], ds['features'].shape)
        ds = get_num_labels(ds)
        ds = check_pre_norm(ds)                
        y = ds['labels'].values.copy().ravel().astype(int)    
        X = ds['features'].values.copy()
        X = convert_nan_to_val(X, value=0)
        X[np.isinf(X)] = 0
        X[X<0] = 0
        if log and ds['pre_norm'] == 'No':
            print('using log')
            X[X<1] = 1
            X = np.log2(X)
        aucs = []
        avg_stat_sig = []
        for i in range(30):
            auc, std,train_size,test_size,clf,multi_auc, num_stat = fit_model(X,y,ds,model)
            aucs.append(auc)
            avg_stat_sig.append(num_stat)
        ds['avg_stat_sig'] = np.asarray(avg_stat_sig).mean()
        aucs = np.asarray(aucs)
        ds['auc'] = aucs.mean()
        ds['auc_std'] = aucs.std()
        ds['train_size'], ds['test_size'], ds['clf'], ds['multi_aucs'] = train_size, test_size, clf, multi_auc
#         ds['auc'], ds['auc_std'], ds['train_size'], ds['test_size'], ds['clf'], ds['multi_aucs'] = fit_model(X, y, ds, model=model)     
        print(ds['auc'],ds['auc_std'])
# Out:
# Feng plasmaall_author (102, 109)

# %%
disease_type = {
    'acute myocardial infarction': 'cardiovascular',
    'cardiovascular': 'cardiovascular',
    'coronary heart disease': 'cardiovascular',
    'hepatocellular carcinoma': 'cancer',
    'Hepatocellular carcinoma': 'cancer',
    'Hepatocellular Carcinoma': 'cancer',
    'hepatitis b': 'infectious',
    'Malaria': 'infectious',
    'Malaria (P. vivax)':'infectious',
    'non-malaria febrile illness':'infectious',
    'scleroderma PAH': 'autoimmune',
    'psoriasis':'autoimmune',
    'pneumonia': 'infectious',
    'Pneumonia - Community acquired': 'infectious',
    'copd': 'respiratory',
    'COPD': 'respiratory',
    'chronic hepatitis B' : 'infectious',
    'typhoid': 'infectious',
    'typhoid carriage':'infectious',
    'lyme': 'infectious',
    'common cold - longitudinal':'infectious',
    'Lyme disease': 'infectious',
    'Alzheimers': 'neurological',
    "Alzheimer's": 'neurological',
    'colorectal cancer': 'cancer',
    'Colorectal Cancer': 'cancer',
    'depression': 'neurological',
    'Depression':'neurological',
    'Breast Cancer': 'cancer',
    'Breast cancer':'cancer',
    'Lung cancer': 'cancer',
    'lung cancer': 'cancer',
    'Lung Cancer': 'cancer',
    'lung cancer - adenocarcinoma': 'cancer',
    'lung cancer - non-small-cell lung cancer (adenocarcinoma, etc)': 'cancer',
    'Stability of dried blood samples - diabetic men' : 'metabolic',
    'Obesity - Non-diabetic and T2 diabetic': 'metabolic',
    't2 diabetes': 'metabolic',
    't1 diabetes': 'metabolic',
    'Diabetes - Type I': 'metabolic',
    'Diabetes - healthy v. T2 v. prediabetic': 'metabolic',
    'Polycystic Ovarian Syndrome': 'metabolic',
    'minimal change disease, focal segmental sclerosis': 'glomerular',
    'interstitial cystitis/painful bladder syndrome': 'other',
    'prepubertal children with obesity': 'other', #MAYBE CHANGE THIS ONE?
    'chronic fatigue syndrome': 'other',
    'Chronic fatigue': 'other',
    'polycystic ovarian syndrome': 'other',
    'scleroderma': 'other',
    'Pregnancy': 'other',
    'smoker v. nonsmoker':'other',
    'Interperson variation':'other',
    'short-term and long-term metabolic changes after bariatric surgery':'other',
    'high intensity exercise metabolomics':'other',
    'Age related metabolomics': 'other',
    'Urine sample storage': 'other',
    'urine metabolome': 'other',
    'Single human time study': 'other'
    }

def make_summary(u,l,i,k,j=0, replace=False):
    if replace:
        auc = u['multi_aucs'].mean(0)[j]
        auc_std = u['multi_aucs'].std(0)[j]
        analysis = u['data_set']+'_'+str(j)
        label = str(l)+str(i)+str(j)
        if model == 'log_reg':
            model_coef = np.count_nonzero(u['clf'].coef_[j])
    else:
        auc = u['auc']
        auc_std = u['auc_std']
        analysis = u['data_set']
        label = str(l)+str(i)
#         if model == 'log_reg':
#             print(u['clf'])
#             model_coef = np.count_nonzero(u['clf'].coef_)
    s = {'disease': u['disease'], 
        'number_labels': 2,
        'auc':auc,
        'auc_std': auc_std,
        'stat_sig_feat':u['avg_stat_sig'],
        'label': label,
        'analysis': analysis,
        'disease_type': disease_type[u['disease']],
        'study': k}
#     if model == 'log_reg':
#         s['model_nonzero_coef'] = model_coef
    return s
    
from string import ascii_letters
summary = []
for l,k in zip(ascii_letters, datasets):
    for i, u in enumerate(datasets[k]):
        if (k == 'ST000062' and u['data_set'] == 'XCMS-Report-annotated-SingleClass-GCTOF.'):
            u['data_set'] = 'XCMS-Report-annotated-SingleClass-GCTOF.plasma'
        if u['num_labels'] == 2:
            control = u['labels']==0
            case = u['labels']==1
            try:
                summed_control = int(control.sum())
                summed_case = int(case.sum())
            except:
                pass
            summary.append(make_summary(u,l,i,k))
        else:
            for j in range(u['num_labels']):
                summary.append(make_summary(u,l,i,k,j=j,replace=True))
                #### Issues with multi class: the case and control just use the last datasets values, not real                      
summary = pd.DataFrame(summary)
# summary = summary.set_index('study')
# summary['disease_type'] = summary['disease_type'].astype('category')
summary
# Out:
#                                               analysis       auc   auc_std  \
# 0                                     plasmaall_author  0.999080  0.000992
# 1                                      urineall_author  0.989681  0.004875
# 2                  serum_IPO_aligned_Feng_serum_batch1  1.000000  0.000000
# 3                  serum_IPO_aligned_Feng_serum_batch2  1.000000  0.000000
# 4                  urine_IPO_aligned_Feng_urine_batch1  0.993389  0.008970
# 5                  urine_IPO_aligned_Feng_urine_batch2  0.961952  0.010023
# 6              serum_onebatch_IPO_align_Feng_serum_all  1.000000  0.000000
# 7            urine_onebatch_IPO_aligned_Feng_urine_all  0.978007  0.004372
# 8                             IPO_aligned_MTBLS105_qMS  0.500000  0.000000
# 9                          IPO_aligned_MTBLS105_SIM-MS  0.722583  0.182575
# 10                                        ulsam_author  0.500000  0.000000
# 11                          ulsam_IPO_reprocessedfirst  0.500000  0.000000
# 12                         ulsam_IPO_reprocessedsecond  0.500000  0.000000
# 13                           ulsam_IPO_reprocessedmean  0.500000  0.000000
# 14                     ulsam_IPO_reprocessedfirst_mean  0.500000  0.000000
# 15                    ulsam_IPO_reprocessedsecond_mean  0.500000  0.000000
# 16                        IPO_aligned_MTBLS17_neg_exp1  0.661001  0.068354
# 17                        IPO_aligned_MTBLS17_neg_exp2  0.500000  0.000000
# 18                        IPO_aligned_MTBLS17_neg_exp3  0.500000  0.000000
# 19                        IPO_aligned_MTBLS17_pos_exp1  0.500000  0.000000
# 20                        IPO_aligned_MTBLS17_pos_exp2  0.500000  0.000000
# 21                        IPO_aligned_MTBLS17_pos_exp3  0.500000  0.000000
# 22                    IPO_aligned_MTBLS17_negall_12_bw  0.661233  0.038458
# 23                   IPO_aligned_MTBLS17_negall_15_ppm  0.673734  0.023065
# 24               IPO_aligned_MTBLS17_negall_1e-1_mzwid  0.658883  0.036018
# 25              IPO_aligned_MTBLS17_negall_1e-4_mzdiff  0.691601  0.011149
# 26               IPO_aligned_MTBLS17_negall_2000_noise  0.609607  0.084612
# 27              IPO_aligned_MTBLS17_negall_25e-3_mzwid  0.677579  0.023269
# 28              IPO_aligned_MTBLS17_negall_3e-2_mzdiff  0.683331  0.023720
# 29              IPO_aligned_MTBLS17_negall_3e-3_mzdiff  0.680065  0.015770
# 30           IPO_aligned_MTBLS17_negall_3_10_peakwidth  0.674831  0.020554
# 31           IPO_aligned_MTBLS17_negall_3_30_peakwidth  0.684762  0.023147
# 32           IPO_aligned_MTBLS17_negall_3_90_peakwidth  0.682591  0.016723
# 33                     IPO_aligned_MTBLS17_negall_4_bw  0.682776  0.018360
# 34            IPO_aligned_MTBLS17_negall_5e-1_profstep  0.688669  0.021773
# 35                 IPO_aligned_MTBLS17_negall_88e-2_bw  0.680275  0.019596
# 36   IPO_aligned_MTBLS17_negall_guess-opt_-1e-4_mzdiff  0.660453  0.019001
# 37    IPO_aligned_MTBLS17_negall_guess-opt_1e-3_mzdiff  0.663822  0.040157
# 38                    IPO_aligned_MTBLS17_neg_onebatch  0.692275  0.019244
# 39                    IPO_aligned_MTBLS17_pos_onebatch  0.574193  0.087898
# 40                                   Peaklist_EXP1_POS  0.522640  0.051187
# 41                                   Peaklist_EXP2_POS  0.500000  0.000000
# 42                                   Peaklist_EXP3_POS  0.500000  0.000000
# 43                                   Peaklist_EXP1_NEG  0.666586  0.037922
# 44                                   Peaklist_EXP2_NEG  0.500000  0.000000
# 45                                   Peaklist_EXP3_NEG  0.500000  0.000000
# 46                                           Exp1F_POS  0.500000  0.000000
# 47                                           Exp1R_POS  0.500000  0.000000
# 48                                           Exp2F_POS  0.500000  0.000000
# 49                                           Exp2R_POS  0.500000  0.000000
# 50                                           Exp1F_NEG  0.500000  0.000000
# 51                                           Exp1R_NEG  0.500000  0.000000
# 52                                           Exp2F_NEG  0.500000  0.000000
# 53                                           Exp2R_NEG  0.500000  0.000000
# 54                      IPO_aligned_MTBLS19_neg_exp1_F  0.500000  0.000000
# 55                      IPO_aligned_MTBLS19_neg_exp1_R  0.500000  0.000000
# 56                      IPO_aligned_MTBLS19_neg_exp2_F  0.500000  0.000000
# 57                      IPO_aligned_MTBLS19_neg_exp2_R  0.500000  0.000000
# 58                      IPO_aligned_MTBLS19_pos_exp1_F  0.500000  0.000000
# 59                      IPO_aligned_MTBLS19_pos_exp1_R  0.500000  0.000000
# 60                      IPO_aligned_MTBLS19_pos_exp2_F  0.500000  0.000000
# 61                      IPO_aligned_MTBLS19_pos_exp2_R  0.500000  0.000000
# 62                     IPO_aligned_MTBLS19_neg_all_F_R  0.700750  0.134167
# 63                     IPO_aligned_MTBLS19_neg_all_R_R  0.574917  0.108112
# 64                     IPO_aligned_MTBLS19_pos_all_F_R  0.763583  0.076367
# 65                     IPO_aligned_MTBLS19_pos_all_R_R  0.505333  0.028721
# 66                            m_oxylipin_chronic_hep_b  0.500000  0.000000
# 67             m_mtbls266_NEG_mass_spectrometry_v2_maf  0.500000  0.000000
# 68             m_mtbls266_POS_mass_spectrometry_v2_maf  0.526667  0.100148
# 69                            IPO_aligned_MTBLS266_neg  0.500000  0.000000
# 70                            IPO_aligned_MTBLS266_pos  0.500000  0.000000
# 71                                 m_chronic_hep_b_POS  0.871914  0.025719
# 72                                 m_chronic_hep_b_NEG  0.907128  0.021040
# 73                                m_mtbls28_NEG_v2_maf  0.792393  0.003626
# 74                                m_mtbls28_POS_v2_maf  0.824466  0.004132
# 75                             IPO_aligned_MTBLS28_neg  0.781543  0.006806
# 76                             IPO_aligned_MTBLS28_pos  0.782534  0.005346
# 77                  m_GC_nmfi_and_bsi_diagnosis_v2_maf  0.500000  0.000000
# 78                  m_LC_nmfi_and_bsi_diagnosis_v2_maf  0.500000  0.000000
# 79            m_UPLC_NEG_nmfi_and_bsi_diagnosis_v2_maf  0.638698  0.142367
# 80            m_UPLC_POS_nmfi_and_bsi_diagnosis_v2_maf  0.719873  0.158487
# 81                         IPO_aligned_MTBLS315_mzData  0.500000  0.000000
# 82                          IPO_aligned_MTBLS315_mzXML  0.500000  0.000000
# 83                         IPO_aligned_MTBLS315_n_mzML  0.848952  0.035718
# 84                         IPO_aligned_MTBLS315_p_mzML  0.922127  0.081743
# 85            DEMO_neg-norm-metaboAnalystInput_T2D_NGT  0.500000  0.000000
# 86         DEMO_neg-norm-metaboAnalystInput_T2D_Pre-DM  0.689619  0.041894
# 87         DEMO_neg-norm-metaboAnalystInput_NGT_Pre-DM  0.500000  0.000000
# 88            DEMO_pos-norm-metaboAnalystInput_T2D_NGT  0.705726  0.069468
# 89         DEMO_pos-norm-metaboAnalystInput_T2D_Pre-DM  0.500000  0.000000
# 90         DEMO_pos-norm-metaboAnalystInput_NGT_Pre-DM  0.500000  0.000000
# 91                    IPO_aligned_MTBLS352_neg_T2D_NGT  0.789156  0.024778
# 92                 IPO_aligned_MTBLS352_neg_T2D_Pre-DM  0.500000  0.000000
# 93                 IPO_aligned_MTBLS352_neg_NGT_Pre-DM  0.500000  0.000000
# 94   m_cap_metabolite_profiling_mass_spectrometry_v...  0.943715  0.003392
# 95   m_cap_metabolite_profiling_mass_spectrometry-1...  0.867857  0.005797
# 96                            IPO_aligned_MTBLS354_neg  0.985584  0.001816
# 97                            IPO_aligned_MTBLS354_pos  0.978254  0.004424
# 98                  m_CER_mass_spectrometry_v4_COPD_FS  0.500000  0.000000
# 99                  m_CER_mass_spectrometry_v4_COPD_CS  0.500000  0.000000
# 100                 m_CER_mass_spectrometry_v4_COPD_NS  0.500000  0.000000
# 101                   m_CER_mass_spectrometry_v4_FS_CS  0.500000  0.000000
# 102                   m_CER_mass_spectrometry_v4_FS_NS  0.500000  0.000000
# 103                   m_CER_mass_spectrometry_v4_CS_NS  0.500000  0.000000
# 104                m_EICO_mass_spectrometry_v4_COPD_FS  0.500000  0.000000
# 105                m_EICO_mass_spectrometry_v4_COPD_CS  0.500000  0.000000
# 106                m_EICO_mass_spectrometry_v4_COPD_NS  0.500000  0.000000
# 107                  m_EICO_mass_spectrometry_v4_FS_CS  0.500000  0.000000
# 108                  m_EICO_mass_spectrometry_v4_FS_NS  0.500000  0.000000
# 109                  m_EICO_mass_spectrometry_v4_CS_NS  0.500000  0.000000
# 110                m_SHOT_mass_spectrometry_v4_COPD_FS  0.500000  0.000000
# 111                m_SHOT_mass_spectrometry_v4_COPD_CS  0.500000  0.000000
# 112                m_SHOT_mass_spectrometry_v4_COPD_NS  0.500000  0.000000
# 113                  m_SHOT_mass_spectrometry_v4_FS_CS  0.500000  0.000000
# 114                  m_SHOT_mass_spectrometry_v4_FS_NS  0.500000  0.000000
# 115                  m_SHOT_mass_spectrometry_v4_CS_NS  0.500000  0.000000
# 116                 m_TAG_mass_spectrometry_v4_COPD_FS  0.500000  0.000000
# 117                 m_TAG_mass_spectrometry_v4_COPD_CS  0.500000  0.000000
# 118                 m_TAG_mass_spectrometry_v4_COPD_NS  0.500000  0.000000
# 119                   m_TAG_mass_spectrometry_v4_FS_CS  0.500000  0.000000
# 120                   m_TAG_mass_spectrometry_v4_FS_NS  0.500000  0.000000
# 121                   m_TAG_mass_spectrometry_v4_CS_NS  0.500000  0.000000
# 122                       IPO_aligned_MTBLS364_hil_neg  0.983488  0.007382
# 123                       IPO_aligned_MTBLS364_hil_pos  0.995322  0.002677
# 124                       IPO_aligned_MTBLS364_lip_neg  0.969350  0.006472
# 125                       IPO_aligned_MTBLS364_lip_pos  0.959906  0.009642
# 126                           IPO_aligned_MTBLS408_neg  0.885185  0.022682
# 127                           IPO_aligned_MTBLS408_pos  0.867819  0.029130
# 128  m_typhoid_carriage_metabolite_profiling_mass_s...  0.909444  0.035469
# 129                            IPO_aligned_MTBLS72_neg  0.500000  0.000000
# 130                            IPO_aligned_MTBLS72_pos  0.500000  0.000000
# 131                                IPO_aligned_MTBLS92  0.500000  0.000000
# 132                                        Author_data  0.525479  0.043266
# 133                                02Feb10-21-r0_ND_II  0.500000  0.000000
# 134                                02Feb10-21-r0_ND_IW  0.500000  0.000000
# 135                                02Feb10-21-r0_II_IW  0.500000  0.000000
# 136                                11Feb10-21-r0_ND_II  0.500000  0.000000
# 137                                11Feb10-21-r0_ND_IW  0.500000  0.000000
# 138                                11Feb10-21-r0_II_IW  0.500000  0.000000
# 139                                11March10-21-_ND_II  0.500000  0.000000
# 140                                11March10-21-_ND_IW  0.500000  0.000000
# 141                                11March10-21-_II_IW  0.500000  0.000000
# 142                                17March10-21-_ND_II  0.500000  0.000000
# 143                                17March10-21-_ND_IW  0.500000  0.000000
# 144                                17March10-21-_II_IW  0.500000  0.000000
# 145                IPO_aligned_ST000045_2feb_pos_ND_II  0.500000  0.000000
# 146                IPO_aligned_ST000045_2feb_pos_ND_IW  0.500000  0.000000
# 147                IPO_aligned_ST000045_2feb_pos_II_IW  0.500000  0.000000
# 148               IPO_aligned_ST000045_11feb_neg_ND_II  0.500000  0.000000
# 149               IPO_aligned_ST000045_11feb_neg_ND_IW  0.500000  0.000000
# 150               IPO_aligned_ST000045_11feb_neg_II_IW  0.500000  0.000000
# 151               IPO_aligned_ST000045_11mar_pos_ND_II  0.500000  0.000000
# 152               IPO_aligned_ST000045_11mar_pos_ND_IW  0.500000  0.000000
# 153               IPO_aligned_ST000045_11mar_pos_II_IW  0.500000  0.000000
# 154               IPO_aligned_ST000045_17mar_neg_ND_II  0.500000  0.000000
# 155               IPO_aligned_ST000045_17mar_neg_ND_IW  0.500000  0.000000
# 156               IPO_aligned_ST000045_17mar_neg_II_IW  0.500000  0.000000
# 157                                    AN000076_CN_MCI  0.500000  0.000000
# 158                                     AN000076_CN_AD  0.500000  0.000000
# 159                                    AN000076_MCI_AD  0.500000  0.000000
# 160                                    AN000077_CN_MCI  0.500000  0.000000
# 161                                     AN000077_CN_AD  0.500000  0.000000
# 162                                    AN000077_MCI_AD  0.500000  0.000000
# 163                                    AN000078_CN_MCI  0.500000  0.000000
# 164                                     AN000078_CN_AD  0.500000  0.000000
# 165                                    AN000078_MCI_AD  0.500000  0.000000
# 166                                    AN000079_CN_MCI  0.500000  0.000000
# 167                                     AN000079_CN_AD  0.500000  0.000000
# 168                                    AN000079_MCI_AD  0.500000  0.000000
# 169     IPO_aligned_ST000046_20120606_neg_hilic_CN_MCI  0.500000  0.000000
# 170      IPO_aligned_ST000046_20120606_neg_hilic_CN_AD  0.500000  0.000000
# 171     IPO_aligned_ST000046_20120606_neg_hilic_MCI_AD  0.500000  0.000000
# 172     IPO_aligned_ST000046_20120613_neg_hilic_CN_MCI  0.500000  0.000000
# 173      IPO_aligned_ST000046_20120613_neg_hilic_CN_AD  0.500000  0.000000
# 174     IPO_aligned_ST000046_20120613_neg_hilic_MCI_AD  0.500000  0.000000
# 175       IPO_aligned_ST000046_20120618_pos_c18_CN_MCI  0.500000  0.000000
# 176        IPO_aligned_ST000046_20120618_pos_c18_CN_AD  0.500000  0.000000
# 177       IPO_aligned_ST000046_20120618_pos_c18_MCI_AD  0.500000  0.000000
# 178       IPO_aligned_ST000046_20120620_neg_c18_CN_MCI  0.500000  0.000000
# 179        IPO_aligned_ST000046_20120620_neg_c18_CN_AD  0.500000  0.000000
# 180       IPO_aligned_ST000046_20120620_neg_c18_MCI_AD  0.500000  0.000000
# 181       IPO_aligned_ST000046_20120625_pos_c18_CN_MCI  0.500000  0.000000
# 182        IPO_aligned_ST000046_20120625_pos_c18_CN_AD  0.500000  0.000000
# 183       IPO_aligned_ST000046_20120625_pos_c18_MCI_AD  0.500000  0.000000
# 184   XCMS-Report-annotated-SingleClass.04jun12_CN_MCI  0.500000  0.000000
# 185    XCMS-Report-annotated-SingleClass.04jun12_CN_AD  0.500000  0.000000
# 186   XCMS-Report-annotated-SingleClass.04jun12_MCI_AD  0.500000  0.000000
# 187   XCMS-Report-annotated-SingleClass.11jun12_CN_MCI  0.500000  0.000000
# 188    XCMS-Report-annotated-SingleClass.11jun12_CN_AD  0.500000  0.000000
# 189   XCMS-Report-annotated-SingleClass.11jun12_MCI_AD  0.911111  0.059074
# 190   XCMS-Report-annotated-SingleClass.27jun12_CN_MCI  0.500000  0.000000
# 191    XCMS-Report-annotated-SingleClass.27jun12_CN_AD  0.500000  0.000000
# 192   XCMS-Report-annotated-SingleClass.27jun12_MCI_AD  0.500000  0.000000
# 193                                           AN000100  0.823355  0.026616
# 194     XCMS-Report-annotated-SingleClass-GCTOF.plasma  0.771381  0.025084
# 195                                           AN000101  0.939398  0.013240
# 196           XCMS-Report-annotated-SingleClass-GCTOF.  0.826022  0.024163
# 197                               AN000452_Healthy_CRC  0.800323  0.021823
# 198                             AN000452_Healthy_Polyp  0.500000  0.000000
# 199                                 AN000452_CRC_Polyp  0.839409  0.024001
# 200                                  AN000525_MCD_FSGS  0.500000  0.000000
# 201                               AN000525_MCD_Control  0.500000  0.000000
# 202                              AN000525_FSGS_Control  0.503333  0.017951
# 203                                  AN000526_MCD_FSGS  0.500000  0.000000
# 204                               AN000526_MCD_Control  0.557778  0.135860
# 205                              AN000526_FSGS_Control  0.500000  0.000000
# 206                  IPO_aligned_ST000329_pos_MCD_FSGS  0.500000  0.000000
# 207               IPO_aligned_ST000329_pos_MCD_Control  0.700000  0.244949
# 208              IPO_aligned_ST000329_pos_FSGS_Control  0.500000  0.000000
# 209                  IPO_aligned_ST000329_neg_MCD_FSGS  0.500000  0.000000
# 210               IPO_aligned_ST000329_neg_MCD_Control  0.500000  0.000000
# 211              IPO_aligned_ST000329_neg_FSGS_Control  0.500000  0.000000
# 212                                           AN000580  0.989409  0.002227
# 213                                           AN000581  0.969763  0.004104
# 214                                           AN000582  0.999009  0.000863
# 215                                           AN000583  1.000000  0.000000
# 216                                           AN000615  0.500000  0.000000
# 217                                           AN000616  0.500000  0.000000
# 218                                           AN000617  0.500000  0.000000
# 219                           IPO_aligned_ST000381_pos  0.500000  0.000000
# 220                                           AN000618  0.957330  0.025345
# 221                                    AN000603_plasma  0.500000  0.000000
# 222                                     AN000603_serum  0.500000  0.000000
# 223                                    AN000620_plasma  0.795118  0.034793
# 224                                     AN000620_serum  0.800486  0.028256
# 225                   IPO_aligned_ST000385_adc2_plasma  0.500000  0.000000
# 226                    IPO_aligned_ST000385_adc2_serum  0.500000  0.000000
# 227                   IPO_aligned_ST000385_adc1_plasma  0.797959  0.034312
# 228                    IPO_aligned_ST000385_adc1_serum  0.757020  0.091509
# 229               IPO_aligned_ST000385_onebatch_plasma  0.500000  0.000000
# 230                IPO_aligned_ST000385_onebatch_serum  0.500000  0.000000
# 231                                        AN000624_LC  0.500000  0.000000
# 232                            IPO_aligned_ST000388_LC  0.500000  0.000000
# 233                                        AN000625_GC  0.500000  0.000000
# 234                            IPO_aligned_ST000388_GC  0.500000  0.000000
# 235                                    AN000628_plasma  0.791330  0.023405
# 236                                     AN000628_serum  0.591134  0.100145
# 237                        IPO_aligned_ST000392_plasma  0.500000  0.000000
# 238                  IPO_aligned_ST000392_plasma_12_bw  0.500000  0.000000
# 239        IPO_aligned_ST000392_plasma_15-25_peakwidth  0.500000  0.000000
# 240           IPO_aligned_ST000392_plasma_1e-1_prefilt  0.500000  0.000000
# 241           IPO_aligned_ST000392_plasma_1e-4_prefilt  0.500000  0.000000
# 242           IPO_aligned_ST000392_plasma_1_5_profstep  0.500000  0.000000
# 243             IPO_aligned_ST000392_plasma_2000_noise  0.505305  0.028567
# 244             IPO_aligned_ST000392_plasma_2e-1_mzwid  0.500000  0.000000
# 245             IPO_aligned_ST000392_plasma_2e-3_mzwid  0.500000  0.000000
# 246         IPO_aligned_ST000392_plasma_4-10_peakwidth  0.500000  0.000000
# 247                   IPO_aligned_ST000392_plasma_4_bw  0.500000  0.000000
# 248                IPO_aligned_ST000392_plasma_5e-1_bw  0.500000  0.000000
# 249          IPO_aligned_ST000392_plasma_5e-1_profstep  0.500000  0.000000
# 250                         IPO_aligned_ST000392_serum  0.500000  0.000000
# 251                   IPO_aligned_ST000392_serum_12_bw  0.500000  0.000000
# 252         IPO_aligned_ST000392_serum_15-25_peakwidth  0.500000  0.000000
# 253             IPO_aligned_ST000392_serum_1e-1_mzdiff  0.500000  0.000000
# 254             IPO_aligned_ST000392_serum_1e-4_mzdiff  0.500000  0.000000
# 255            IPO_aligned_ST000392_serum_1_5_profstep  0.500000  0.000000
# 256              IPO_aligned_ST000392_serum_2000_noise  0.500000  0.000000
# 257              IPO_aligned_ST000392_serum_2e-1_mzwid  0.500000  0.000000
# 258              IPO_aligned_ST000392_serum_2e-3_mzwid  0.500000  0.000000
# 259          IPO_aligned_ST000392_serum_4-10_peakwidth  0.500000  0.000000
# 260                    IPO_aligned_ST000392_serum_4_bw  0.500000  0.000000
# 261                 IPO_aligned_ST000392_serum_5e-1_bw  0.500000  0.000000
# 262           IPO_aligned_ST000392_serum_5e-1_profstep  0.500000  0.000000
# 263                                           AN000633  0.500000  0.000000
# 264                               IPO_aligned_ST000396  0.500000  0.000000
# 265                                           AN000705  0.908439  0.016662
# 266                                           AN000706  0.500000  0.000000
# 267                                           AN000888  0.965483  0.006012
# 268                                           AN000889  0.932302  0.010721
# 269                            IPO_aligned_ST000578_AE  0.924605  0.014453
# 270                           IPO_aligned_ST000578_C18  0.960634  0.004574
# 271                                           AN000929  0.616667  0.194222
# 272                                           AN000930  0.500000  0.000000
# 273                                           AN000931  0.500000  0.000000
# 274                               AN001201_Healthy_PAH  0.842398  0.018814
# 275                  AN001201_Healthy_Normal Pressures  0.909222  0.010319
# 276              AN001201_Healthy_Borderline Pressures  0.865376  0.014738
# 277                           AN001201_Healthy_LowRisk  0.648478  0.139534
# 278                      AN001201_PAH_Normal Pressures  0.500000  0.000000
# 279                  AN001201_PAH_Borderline Pressures  0.500000  0.000000
# 280                               AN001201_PAH_LowRisk  0.506865  0.036970
# 281     AN001201_Normal Pressures_Borderline Pressures  0.500000  0.000000
# 282                  AN001201_Normal Pressures_LowRisk  0.824028  0.034965
# 283              AN001201_Borderline Pressures_LowRisk  0.554528  0.100063
# 284                               AN001202_Healthy_PAH  0.828086  0.021296
# 285                  AN001202_Healthy_Normal Pressures  0.874103  0.020778
# 286              AN001202_Healthy_Borderline Pressures  0.824374  0.022236
# 287                           AN001202_Healthy_LowRisk  0.500000  0.000000
# 288                      AN001202_PAH_Normal Pressures  0.500000  0.000000
# 289                  AN001202_PAH_Borderline Pressures  0.500000  0.000000
# 290                               AN001202_PAH_LowRisk  0.500000  0.000000
# 291     AN001202_Normal Pressures_Borderline Pressures  0.500000  0.000000
# 292                  AN001202_Normal Pressures_LowRisk  0.676759  0.109940
# 293              AN001202_Borderline Pressures_LowRisk  0.526924  0.081429
# 294         IPO_aligned_ST000763_untar_pos_Healthy_PAH  0.835080  0.013394
# 295  IPO_aligned_ST000763_untar_pos_Healthy_Normal ...  0.913548  0.010446
# 296  IPO_aligned_ST000763_untar_pos_Healthy_Borderl...  0.896030  0.009071
# 297     IPO_aligned_ST000763_untar_pos_Healthy_LowRisk  0.810352  0.025576
# 298  IPO_aligned_ST000763_untar_pos_PAH_Normal Pres...  0.500000  0.000000
# 299  IPO_aligned_ST000763_untar_pos_PAH_Borderline ...  0.500000  0.000000
# 300         IPO_aligned_ST000763_untar_pos_PAH_LowRisk  0.757407  0.033647
# 301  IPO_aligned_ST000763_untar_pos_Normal Pressure...  0.500000  0.000000
# 302  IPO_aligned_ST000763_untar_pos_Normal Pressure...  0.910347  0.019576
# 303  IPO_aligned_ST000763_untar_pos_Borderline Pres...  0.878086  0.022465
# 304         IPO_aligned_ST000763_untar_neg_Healthy_PAH  0.836015  0.013498
# 305  IPO_aligned_ST000763_untar_neg_Healthy_Normal ...  0.918905  0.015616
# 306  IPO_aligned_ST000763_untar_neg_Healthy_Borderl...  0.885938  0.007303
# 307     IPO_aligned_ST000763_untar_neg_Healthy_LowRisk  0.799207  0.022778
# 308  IPO_aligned_ST000763_untar_neg_PAH_Normal Pres...  0.500000  0.000000
# 309  IPO_aligned_ST000763_untar_neg_PAH_Borderline ...  0.500000  0.000000
# 310         IPO_aligned_ST000763_untar_neg_PAH_LowRisk  0.555569  0.103645
# 311  IPO_aligned_ST000763_untar_neg_Normal Pressure...  0.500000  0.000000
# 312  IPO_aligned_ST000763_untar_neg_Normal Pressure...  0.900648  0.026365
# 313  IPO_aligned_ST000763_untar_neg_Borderline Pres...  0.787176  0.030211
# 314                                 AN001390all_author  0.500000  0.000000
# 315                    IPO_aligned_ST000865_batch2_raw  0.500000  0.000000
# 316                    IPO_aligned_ST000865_batch3_raw  0.500000  0.000000
# 317                      IPO_aligned_ST000865_onebatch  0.500000  0.000000
# 318                                           AN001450  0.996386  0.000742
# 319                                           AN001503  0.500000  0.000000
#
#                                                disease    disease_type label  \
# 0                               coronary heart disease  cardiovascular    a0
# 1                               coronary heart disease  cardiovascular    a1
# 2                               coronary heart disease  cardiovascular    a2
# 3                               coronary heart disease  cardiovascular    a3
# 4                               coronary heart disease  cardiovascular    a4
# 5                               coronary heart disease  cardiovascular    a5
# 6                               coronary heart disease  cardiovascular    a6
# 7                               coronary heart disease  cardiovascular    a7
# 8                             Hepatocellular carcinoma          cancer    b0
# 9                             Hepatocellular carcinoma          cancer    b1
# 10                         acute myocardial infarction  cardiovascular    c0
# 11                         acute myocardial infarction  cardiovascular    c1
# 12                         acute myocardial infarction  cardiovascular    c2
# 13                         acute myocardial infarction  cardiovascular    c3
# 14                         acute myocardial infarction  cardiovascular    c4
# 15                         acute myocardial infarction  cardiovascular    c5
# 16                            hepatocellular carcinoma          cancer    d0
# 17                            hepatocellular carcinoma          cancer    d1
# 18                            hepatocellular carcinoma          cancer    d2
# 19                            hepatocellular carcinoma          cancer    d3
# 20                            hepatocellular carcinoma          cancer    d4
# 21                            hepatocellular carcinoma          cancer    d5
# 22                            hepatocellular carcinoma          cancer    d6
# 23                            hepatocellular carcinoma          cancer    d7
# 24                            hepatocellular carcinoma          cancer    d8
# 25                            hepatocellular carcinoma          cancer    d9
# 26                            hepatocellular carcinoma          cancer   d10
# 27                            hepatocellular carcinoma          cancer   d11
# 28                            hepatocellular carcinoma          cancer   d12
# 29                            hepatocellular carcinoma          cancer   d13
# 30                            hepatocellular carcinoma          cancer   d14
# 31                            hepatocellular carcinoma          cancer   d15
# 32                            hepatocellular carcinoma          cancer   d16
# 33                            hepatocellular carcinoma          cancer   d17
# 34                            hepatocellular carcinoma          cancer   d18
# 35                            hepatocellular carcinoma          cancer   d19
# 36                            hepatocellular carcinoma          cancer   d20
# 37                            hepatocellular carcinoma          cancer   d21
# 38                            hepatocellular carcinoma          cancer   d22
# 39                            hepatocellular carcinoma          cancer   d23
# 40                            hepatocellular carcinoma          cancer   d24
# 41                            hepatocellular carcinoma          cancer   d25
# 42                            hepatocellular carcinoma          cancer   d26
# 43                            hepatocellular carcinoma          cancer   d27
# 44                            hepatocellular carcinoma          cancer   d28
# 45                            hepatocellular carcinoma          cancer   d29
# 46                            hepatocellular carcinoma          cancer    e0
# 47                            hepatocellular carcinoma          cancer    e1
# 48                            hepatocellular carcinoma          cancer    e2
# 49                            hepatocellular carcinoma          cancer    e3
# 50                            hepatocellular carcinoma          cancer    e4
# 51                            hepatocellular carcinoma          cancer    e5
# 52                            hepatocellular carcinoma          cancer    e6
# 53                            hepatocellular carcinoma          cancer    e7
# 54                            hepatocellular carcinoma          cancer    e8
# 55                            hepatocellular carcinoma          cancer    e9
# 56                            hepatocellular carcinoma          cancer   e10
# 57                            hepatocellular carcinoma          cancer   e11
# 58                            hepatocellular carcinoma          cancer   e12
# 59                            hepatocellular carcinoma          cancer   e13
# 60                            hepatocellular carcinoma          cancer   e14
# 61                            hepatocellular carcinoma          cancer   e15
# 62                            hepatocellular carcinoma          cancer   e16
# 63                            hepatocellular carcinoma          cancer   e17
# 64                            hepatocellular carcinoma          cancer   e18
# 65                            hepatocellular carcinoma          cancer   e19
# 66                                 chronic hepatitis B      infectious    f0
# 67                            Age related metabolomics           other    g0
# 68                            Age related metabolomics           other    g1
# 69                            Age related metabolomics           other    g2
# 70                            Age related metabolomics           other    g3
# 71                                 chronic hepatitis B      infectious    h0
# 72                                 chronic hepatitis B      infectious    h1
# 73                                         Lung cancer          cancer    i0
# 74                                         Lung cancer          cancer    i1
# 75                                         Lung cancer          cancer    i2
# 76                                         Lung cancer          cancer    i3
# 77                         non-malaria febrile illness      infectious    j0
# 78                         non-malaria febrile illness      infectious    j1
# 79                         non-malaria febrile illness      infectious    j2
# 80                         non-malaria febrile illness      infectious    j3
# 81                         non-malaria febrile illness      infectious    j4
# 82                         non-malaria febrile illness      infectious    j5
# 83                         non-malaria febrile illness      infectious    j6
# 84                         non-malaria febrile illness      infectious    j7
# 85             Diabetes - healthy v. T2 v. prediabetic       metabolic    k0
# 86             Diabetes - healthy v. T2 v. prediabetic       metabolic    k1
# 87             Diabetes - healthy v. T2 v. prediabetic       metabolic    k2
# 88             Diabetes - healthy v. T2 v. prediabetic       metabolic    k3
# 89             Diabetes - healthy v. T2 v. prediabetic       metabolic    k4
# 90             Diabetes - healthy v. T2 v. prediabetic       metabolic    k5
# 91             Diabetes - healthy v. T2 v. prediabetic       metabolic    k6
# 92             Diabetes - healthy v. T2 v. prediabetic       metabolic    k7
# 93             Diabetes - healthy v. T2 v. prediabetic       metabolic    k8
# 94                      Pneumonia - Community acquired      infectious    l0
# 95                      Pneumonia - Community acquired      infectious    l1
# 96                      Pneumonia - Community acquired      infectious    l2
# 97                      Pneumonia - Community acquired      infectious    l3
# 98                                                COPD     respiratory    m0
# 99                                                COPD     respiratory    m1
# 100                                               COPD     respiratory    m2
# 101                                               COPD     respiratory    m3
# 102                                               COPD     respiratory    m4
# 103                                               COPD     respiratory    m5
# 104                                               COPD     respiratory    m6
# 105                                               COPD     respiratory    m7
# 106                                               COPD     respiratory    m8
# 107                                               COPD     respiratory    m9
# 108                                               COPD     respiratory   m10
# 109                                               COPD     respiratory   m11
# 110                                               COPD     respiratory   m12
# 111                                               COPD     respiratory   m13
# 112                                               COPD     respiratory   m14
# 113                                               COPD     respiratory   m15
# 114                                               COPD     respiratory   m16
# 115                                               COPD     respiratory   m17
# 116                                               COPD     respiratory   m18
# 117                                               COPD     respiratory   m19
# 118                                               COPD     respiratory   m20
# 119                                               COPD     respiratory   m21
# 120                                               COPD     respiratory   m22
# 121                                               COPD     respiratory   m23
# 122                                smoker v. nonsmoker           other    n0
# 123                                smoker v. nonsmoker           other    n1
# 124                                smoker v. nonsmoker           other    n2
# 125                                smoker v. nonsmoker           other    n3
# 126                                          psoriasis      autoimmune    o0
# 127                                          psoriasis      autoimmune    o1
# 128                                   typhoid carriage      infectious    p0
# 129                                         Alzheimers    neurological    q0
# 130                                         Alzheimers    neurological    q1
# 131                                      Breast Cancer          cancer    r0
# 132                                      Breast Cancer          cancer    r1
# 133                                        t1 diabetes       metabolic    s0
# 134                                        t1 diabetes       metabolic    s1
# 135                                        t1 diabetes       metabolic    s2
# 136                                        t1 diabetes       metabolic    s3
# 137                                        t1 diabetes       metabolic    s4
# 138                                        t1 diabetes       metabolic    s5
# 139                                        t1 diabetes       metabolic    s6
# 140                                        t1 diabetes       metabolic    s7
# 141                                        t1 diabetes       metabolic    s8
# 142                                        t1 diabetes       metabolic    s9
# 143                                        t1 diabetes       metabolic   s10
# 144                                        t1 diabetes       metabolic   s11
# 145                                        t1 diabetes       metabolic   s12
# 146                                        t1 diabetes       metabolic   s13
# 147                                        t1 diabetes       metabolic   s14
# 148                                        t1 diabetes       metabolic   s15
# 149                                        t1 diabetes       metabolic   s16
# 150                                        t1 diabetes       metabolic   s17
# 151                                        t1 diabetes       metabolic   s18
# 152                                        t1 diabetes       metabolic   s19
# 153                                        t1 diabetes       metabolic   s20
# 154                                        t1 diabetes       metabolic   s21
# 155                                        t1 diabetes       metabolic   s22
# 156                                        t1 diabetes       metabolic   s23
# 157                                        Alzheimer's    neurological    t0
# 158                                        Alzheimer's    neurological    t1
# 159                                        Alzheimer's    neurological    t2
# 160                                        Alzheimer's    neurological    t3
# 161                                        Alzheimer's    neurological    t4
# 162                                        Alzheimer's    neurological    t5
# 163                                        Alzheimer's    neurological    t6
# 164                                        Alzheimer's    neurological    t7
# 165                                        Alzheimer's    neurological    t8
# 166                                        Alzheimer's    neurological    t9
# 167                                        Alzheimer's    neurological   t10
# 168                                        Alzheimer's    neurological   t11
# 169                                        Alzheimer's    neurological   t12
# 170                                        Alzheimer's    neurological   t13
# 171                                        Alzheimer's    neurological   t14
# 172                                        Alzheimer's    neurological   t15
# 173                                        Alzheimer's    neurological   t16
# 174                                        Alzheimer's    neurological   t17
# 175                                        Alzheimer's    neurological   t18
# 176                                        Alzheimer's    neurological   t19
# 177                                        Alzheimer's    neurological   t20
# 178                                        Alzheimer's    neurological   t21
# 179                                        Alzheimer's    neurological   t22
# 180                                        Alzheimer's    neurological   t23
# 181                                        Alzheimer's    neurological   t24
# 182                                        Alzheimer's    neurological   t25
# 183                                        Alzheimer's    neurological   t26
# 184                                        Alzheimer's    neurological   t27
# 185                                        Alzheimer's    neurological   t28
# 186                                        Alzheimer's    neurological   t29
# 187                                        Alzheimer's    neurological   t30
# 188                                        Alzheimer's    neurological   t31
# 189                                        Alzheimer's    neurological   t32
# 190                                        Alzheimer's    neurological   t33
# 191                                        Alzheimer's    neurological   t34
# 192                                        Alzheimer's    neurological   t35
# 193                                         Depression    neurological    u0
# 194                                         Depression    neurological    u1
# 195                                         Depression    neurological    v0
# 196                                         Depression    neurological    v1
# 197                                  Colorectal Cancer          cancer    w0
# 198                                  Colorectal Cancer          cancer    w1
# 199                                  Colorectal Cancer          cancer    w2
# 200  minimal change disease, focal segmental sclerosis      glomerular    x0
# 201  minimal change disease, focal segmental sclerosis      glomerular    x1
# 202  minimal change disease, focal segmental sclerosis      glomerular    x2
# 203  minimal change disease, focal segmental sclerosis      glomerular    x3
# 204  minimal change disease, focal segmental sclerosis      glomerular    x4
# 205  minimal change disease, focal segmental sclerosis      glomerular    x5
# 206  minimal change disease, focal segmental sclerosis      glomerular    x6
# 207  minimal change disease, focal segmental sclerosis      glomerular    x7
# 208  minimal change disease, focal segmental sclerosis      glomerular    x8
# 209  minimal change disease, focal segmental sclerosis      glomerular    x9
# 210  minimal change disease, focal segmental sclerosis      glomerular   x10
# 211  minimal change disease, focal segmental sclerosis      glomerular   x11
# 212                                      Breast Cancer          cancer    y0
# 213                                      Breast Cancer          cancer    y1
# 214                                      Breast Cancer          cancer    z0
# 215                                      Breast Cancer          cancer    z1
# 216     interstitial cystitis/painful bladder syndrome           other    A0
# 217     interstitial cystitis/painful bladder syndrome           other    A1
# 218     interstitial cystitis/painful bladder syndrome           other    A2
# 219     interstitial cystitis/painful bladder syndrome           other    A3
# 220             Obesity - Non-diabetic and T2 diabetic       metabolic    B0
# 221                       lung cancer - adenocarcinoma          cancer    C0
# 222                       lung cancer - adenocarcinoma          cancer    C1
# 223                       lung cancer - adenocarcinoma          cancer    C2
# 224                       lung cancer - adenocarcinoma          cancer    C3
# 225                       lung cancer - adenocarcinoma          cancer    C4
# 226                       lung cancer - adenocarcinoma          cancer    C5
# 227                       lung cancer - adenocarcinoma          cancer    C6
# 228                       lung cancer - adenocarcinoma          cancer    C7
# 229                       lung cancer - adenocarcinoma          cancer    C8
# 230                       lung cancer - adenocarcinoma          cancer    C9
# 231                                        Lung cancer          cancer    D0
# 232                                        Lung cancer          cancer    D1
# 233                                        Lung cancer          cancer    E0
# 234                                        Lung cancer          cancer    E1
# 235                                        Lung cancer          cancer    F0
# 236                                        Lung cancer          cancer    F1
# 237                                        Lung cancer          cancer    F2
# 238                                        Lung cancer          cancer    F3
# 239                                        Lung cancer          cancer    F4
# 240                                        Lung cancer          cancer    F5
# 241                                        Lung cancer          cancer    F6
# 242                                        Lung cancer          cancer    F7
# 243                                        Lung cancer          cancer    F8
# 244                                        Lung cancer          cancer    F9
# 245                                        Lung cancer          cancer   F10
# 246                                        Lung cancer          cancer   F11
# 247                                        Lung cancer          cancer   F12
# 248                                        Lung cancer          cancer   F13
# 249                                        Lung cancer          cancer   F14
# 250                                        Lung cancer          cancer   F15
# 251                                        Lung cancer          cancer   F16
# 252                                        Lung cancer          cancer   F17
# 253                                        Lung cancer          cancer   F18
# 254                                        Lung cancer          cancer   F19
# 255                                        Lung cancer          cancer   F20
# 256                                        Lung cancer          cancer   F21
# 257                                        Lung cancer          cancer   F22
# 258                                        Lung cancer          cancer   F23
# 259                                        Lung cancer          cancer   F24
# 260                                        Lung cancer          cancer   F25
# 261                                        Lung cancer          cancer   F26
# 262                                        Lung cancer          cancer   F27
# 263  lung cancer - non-small-cell lung cancer (aden...          cancer    G0
# 264  lung cancer - non-small-cell lung cancer (aden...          cancer    G1
# 265                                    Chronic fatigue           other    H0
# 266                                    Chronic fatigue           other    H1
# 267                                 Malaria (P. vivax)      infectious    I0
# 268                                 Malaria (P. vivax)      infectious    I1
# 269                                 Malaria (P. vivax)      infectious    I2
# 270                                 Malaria (P. vivax)      infectious    I3
# 271    Stability of dried blood samples - diabetic men       metabolic    J0
# 272    Stability of dried blood samples - diabetic men       metabolic    J1
# 273    Stability of dried blood samples - diabetic men       metabolic    J2
# 274                                    scleroderma PAH      autoimmune    K0
# 275                                    scleroderma PAH      autoimmune    K1
# 276                                    scleroderma PAH      autoimmune    K2
# 277                                    scleroderma PAH      autoimmune    K3
# 278                                    scleroderma PAH      autoimmune    K4
# 279                                    scleroderma PAH      autoimmune    K5
# 280                                    scleroderma PAH      autoimmune    K6
# 281                                    scleroderma PAH      autoimmune    K7
# 282                                    scleroderma PAH      autoimmune    K8
# 283                                    scleroderma PAH      autoimmune    K9
# 284                                    scleroderma PAH      autoimmune   K10
# 285                                    scleroderma PAH      autoimmune   K11
# ...
# 305                                    scleroderma PAH      autoimmune   K31
# 306                                    scleroderma PAH      autoimmune   K32
# 307                                    scleroderma PAH      autoimmune   K33
# 308                                    scleroderma PAH      autoimmune   K34
# 309                                    scleroderma PAH      autoimmune   K35
# 310                                    scleroderma PAH      autoimmune   K36
# 311                                    scleroderma PAH      autoimmune   K37
# 312                                    scleroderma PAH      autoimmune   K38
# 313                                    scleroderma PAH      autoimmune   K39
# 314                           Hepatocellular Carcinoma          cancer    L0
# 315                           Hepatocellular Carcinoma          cancer    L1
# 316                           Hepatocellular Carcinoma          cancer    L2
# 317                           Hepatocellular Carcinoma          cancer    L3
# 318                                       Lyme disease      infectious    M0
# 319                                      Breast cancer          cancer    N0
#
#      number_labels  stat_sig_feat     study
# 0                2     106.766667      Feng
# 1                2     156.513333      Feng
# 2                2    1213.200000      Feng
# 3                2     914.866667      Feng
# 4                2    1133.846667      Feng
# 5                2    1644.926667      Feng
# 6                2    1319.226667      Feng
# 7                2    2203.440000      Feng
# 8                2       0.000000  MTBLS105
# 9                2       3.719444  MTBLS105
# 10               2       0.000000  MTBLS124
# 11               2       0.183333  MTBLS124
# 12               2       5.600000  MTBLS124
# 13               2       0.000000  MTBLS124
# 14               2       0.000000  MTBLS124
# 15               2       3.283333  MTBLS124
# 16               2     288.957778   MTBLS17
# 17               2       0.000000   MTBLS17
# 18               2       0.000000   MTBLS17
# 19               2      34.077778   MTBLS17
# 20               2       0.000000   MTBLS17
# 21               2       0.000000   MTBLS17
# 22               2     132.606667   MTBLS17
# 23               2      84.786667   MTBLS17
# 24               2     205.668333   MTBLS17
# 25               2     216.353333   MTBLS17
# 26               2       6.380000   MTBLS17
# 27               2     219.586667   MTBLS17
# 28               2     213.180000   MTBLS17
# 29               2     219.086667   MTBLS17
# 30               2     160.726667   MTBLS17
# 31               2     201.526667   MTBLS17
# 32               2     212.986667   MTBLS17
# 33               2     170.713333   MTBLS17
# 34               2     194.986667   MTBLS17
# 35               2     249.746667   MTBLS17
# 36               2      76.446667   MTBLS17
# 37               2      67.105000   MTBLS17
# 38               2     286.700000   MTBLS17
# 39               2      63.787222   MTBLS17
# 40               2      18.219444   MTBLS17
# 41               2       0.000000   MTBLS17
# 42               2       0.000000   MTBLS17
# 43               2     116.846667   MTBLS17
# 44               2       0.000000   MTBLS17
# 45               2       0.000000   MTBLS17
# 46               2       0.766667   MTBLS19
# 47               2       1.927778   MTBLS19
# 48               2      13.420556   MTBLS19
# 49               2       0.466667   MTBLS19
# 50               2       2.333333   MTBLS19
# 51               2       1.233333   MTBLS19
# 52               2       5.133333   MTBLS19
# 53               2       1.050000   MTBLS19
# 54               2       2.038889   MTBLS19
# 55               2       1.891667   MTBLS19
# 56               2       3.083333   MTBLS19
# 57               2       0.166667   MTBLS19
# 58               2       0.650000   MTBLS19
# 59               2       0.233333   MTBLS19
# 60               2       5.066667   MTBLS19
# 61               2       0.433333   MTBLS19
# 62               2     121.770556   MTBLS19
# 63               2      60.631667   MTBLS19
# 64               2     115.430000   MTBLS19
# 65               2      34.740556   MTBLS19
# 66               2       0.816667  MTBLS253
# 67               2       0.266667  MTBLS266
# 68               2       2.117778  MTBLS266
# 69               2       5.266667  MTBLS266
# 70               2       0.000000  MTBLS266
# 71               2      27.173333  MTBLS279
# 72               2      20.873333  MTBLS279
# 73               2     602.513333   MTBLS28
# 74               2     811.433333   MTBLS28
# 75               2    1040.586667   MTBLS28
# 76               2    1797.780000   MTBLS28
# 77               2       0.300000  MTBLS315
# 78               2       6.833333  MTBLS315
# 79               2     162.117778  MTBLS315
# 80               2     157.536667  MTBLS315
# 81               2       0.416667  MTBLS315
# 82               2       5.341667  MTBLS315
# 83               2      30.406667  MTBLS315
# 84               2      23.021667  MTBLS315
# 85               2       0.216667  MTBLS352
# 86               2       3.560000  MTBLS352
# 87               2       0.533333  MTBLS352
# 88               2       4.248889  MTBLS352
# 89               2       0.433333  MTBLS352
# 90               2       0.633333  MTBLS352
# 91               2      16.286667  MTBLS352
# 92               2       2.600000  MTBLS352
# 93               2       0.216667  MTBLS352
# 94               2       7.000000  MTBLS354
# 95               2       5.000000  MTBLS354
# 96               2    5242.646667  MTBLS354
# 97               2   11882.793333  MTBLS354
# 98               2       0.033333  MTBLS358
# 99               2       0.000000  MTBLS358
# 100              2       0.000000  MTBLS358
# 101              2       0.033333  MTBLS358
# 102              2       0.000000  MTBLS358
# 103              2       0.066667  MTBLS358
# 104              2       0.066667  MTBLS358
# 105              2       0.000000  MTBLS358
# 106              2       0.400000  MTBLS358
# 107              2       0.300000  MTBLS358
# 108              2       0.000000  MTBLS358
# 109              2       0.000000  MTBLS358
# 110              2       0.600000  MTBLS358
# 111              2       0.250000  MTBLS358
# 112              2       1.477778  MTBLS358
# 113              2       0.033333  MTBLS358
# 114              2       0.000000  MTBLS358
# 115              2       0.033333  MTBLS358
# 116              2       0.377778  MTBLS358
# 117              2       0.000000  MTBLS358
# 118              2       2.919444  MTBLS358
# 119              2       0.116667  MTBLS358
# 120              2       0.000000  MTBLS358
# 121              2       0.316667  MTBLS358
# 122              2    3630.240000  MTBLS364
# 123              2   10141.760000  MTBLS364
# 124              2     425.233333  MTBLS364
# 125              2    3374.620000  MTBLS364
# 126              2     170.713333  MTBLS408
# 127              2     151.993333  MTBLS408
# 128              2      15.820000  MTBLS579
# 129              2       1.083333   MTBLS72
# 130              2       0.233333   MTBLS72
# 131              2       1.083333   MTBLS92
# 132              2       8.230556   MTBLS92
# 133              2       0.000000  ST000045
# 134              2       0.000000  ST000045
# 135              2       0.000000  ST000045
# 136              2       0.000000  ST000045
# 137              2       0.000000  ST000045
# 138              2       0.000000  ST000045
# 139              2       0.000000  ST000045
# 140              2       0.000000  ST000045
# 141              2       0.000000  ST000045
# 142              2       0.000000  ST000045
# 143              2       0.000000  ST000045
# 144              2       0.000000  ST000045
# 145              2       0.000000  ST000045
# 146              2       0.000000  ST000045
# 147              2       0.000000  ST000045
# 148              2       0.000000  ST000045
# 149              2       0.000000  ST000045
# 150              2       0.000000  ST000045
# 151              2       0.000000  ST000045
# 152              2       0.000000  ST000045
# 153              2       0.000000  ST000045
# 154              2       0.000000  ST000045
# 155              2       0.000000  ST000045
# 156              2       0.000000  ST000045
# 157              2       0.000000  ST000046
# 158              2       0.000000  ST000046
# 159              2       0.000000  ST000046
# 160              2       0.000000  ST000046
# 161              2       0.000000  ST000046
# 162              2       0.000000  ST000046
# 163              2       0.000000  ST000046
# 164              2       0.000000  ST000046
# 165              2       0.000000  ST000046
# 166              2       0.000000  ST000046
# 167              2       0.000000  ST000046
# 168              2       0.000000  ST000046
# 169              2       0.000000  ST000046
# 170              2       0.000000  ST000046
# 171              2       0.000000  ST000046
# 172              2       0.000000  ST000046
# 173              2       0.000000  ST000046
# 174              2       0.000000  ST000046
# 175              2       0.000000  ST000046
# 176              2       0.000000  ST000046
# 177              2       0.000000  ST000046
# 178              2       0.000000  ST000046
# 179              2       0.000000  ST000046
# 180              2       0.000000  ST000046
# 181              2       0.000000  ST000046
# 182              2       0.000000  ST000046
# 183              2       0.000000  ST000046
# 184              2       0.000000  ST000046
# 185              2       0.516667  ST000046
# 186              2       0.116667  ST000046
# 187              2       0.233333  ST000046
# 188              2       1.666667  ST000046
# 189              2      10.040000  ST000046
# 190              2       0.600000  ST000046
# 191              2       0.466667  ST000046
# 192              2       0.000000  ST000046
# 193              2      18.360000  ST000062
# 194              2     804.666667  ST000062
# 195              2      66.026667  ST000063
# 196              2     441.986667  ST000063
# 197              2      17.900000  ST000284
# 198              2       0.000000  ST000284
# 199              2      23.673333  ST000284
# 200              2       0.000000  ST000329
# 201              2       9.093889  ST000329
# 202              2      11.487778  ST000329
# 203              2       0.000000  ST000329
# 204              2       8.441111  ST000329
# 205              2       3.655556  ST000329
# 206              2       0.000000  ST000329
# 207              2      86.806667  ST000329
# 208              2       0.000000  ST000329
# 209              2       0.000000  ST000329
# 210              2       2.650000  ST000329
# 211              2       0.000000  ST000329
# 212              2      46.513333  ST000355
# 213              2      40.273333  ST000355
# 214              2      66.860000  ST000356
# 215              2     105.686667  ST000356
# 216              2       0.033333  ST000381
# 217              2       0.000000  ST000381
# 218              2       0.000000  ST000381
# 219              2       0.000000  ST000381
# 220              2      10.793333  ST000383
# 221              2       1.350000  ST000385
# 222              2       0.350000  ST000385
# 223              2      15.746667  ST000385
# 224              2      14.193333  ST000385
# 225              2       0.000000  ST000385
# 226              2       0.083333  ST000385
# 227              2      52.560000  ST000385
# 228              2      30.296111  ST000385
# 229              2       0.900000  ST000385
# 230              2       1.483333  ST000385
# 231              2       0.000000  ST000388
# 232              2       0.000000  ST000388
# 233              2       0.233333  ST000389
# 234              2       0.000000  ST000389
# 235              2      18.840000  ST000392
# 236              2       4.821111  ST000392
# 237              2       5.725000  ST000392
# 238              2       2.338889  ST000392
# 239              2       6.010556  ST000392
# 240              2       7.325000  ST000392
# 241              2       5.894444  ST000392
# 242              2       3.416667  ST000392
# 243              2       7.022222  ST000392
# 244              2       4.398333  ST000392
# 245              2       3.120556  ST000392
# 246              2       7.538889  ST000392
# 247              2       7.186111  ST000392
# 248              2       6.213889  ST000392
# 249              2       6.442222  ST000392
# 250              2       0.033333  ST000392
# 251              2       0.033333  ST000392
# 252              2       0.766667  ST000392
# 253              2       0.583333  ST000392
# 254              2       0.033333  ST000392
# 255              2       0.066667  ST000392
# 256              2       0.100000  ST000392
# 257              2       0.133333  ST000392
# 258              2       0.100000  ST000392
# 259              2       0.450000  ST000392
# 260              2       0.133333  ST000392
# 261              2       0.183333  ST000392
# 262              2       0.033333  ST000392
# 263              2       0.000000  ST000396
# 264              2       0.133333  ST000396
# 265              2      29.566667  ST000450
# 266              2       0.050000  ST000450
# 267              2    3364.746667  ST000578
# 268              2    2794.533333  ST000578
# 269              2    4955.920000  ST000578
# 270              2    7381.620000  ST000578
# 271              2      12.715000  ST000608
# 272              2       0.116667  ST000608
# 273              2       0.000000  ST000608
# 274              2      29.433333  ST000763
# 275              2      25.586667  ST000763
# 276              2      27.386667  ST000763
# 277              2       4.334444  ST000763
# 278              2       0.266667  ST000763
# 279              2       0.300000  ST000763
# 280              2       5.892222  ST000763
# 281              2       0.100000  ST000763
# 282              2       9.106667  ST000763
# 283              2       4.986667  ST000763
# 284              2      21.346667  ST000763
# 285              2      23.553333  ST000763
# 286              2      19.546667  ST000763
# 287              2       0.816667  ST000763
# 288              2       0.000000  ST000763
# 289              2       0.066667  ST000763
# 290              2       2.048889  ST000763
# 291              2       0.050000  ST000763
# 292              2       6.966667  ST000763
# 293              2       3.097222  ST000763
# 294              2    8769.220000  ST000763
# 295              2    4719.466667  ST000763
# 296              2    5908.793333  ST000763
# 297              2     249.266667  ST000763
# 298              2      11.033333  ST000763
# 299              2       0.116667  ST000763
# 300              2    3300.840000  ST000763
# 301              2       0.000000  ST000763
# 302              2    1110.653333  ST000763
# 303              2    1956.293333  ST000763
# 304              2    6540.400000  ST000763
# 305              2    4018.060000  ST000763
# 306              2    5202.120000  ST000763
# 307              2     380.766667  ST000763
# 308              2       1.716667  ST000763
# 309              2       0.066667  ST000763
# 310              2     521.085000  ST000763
# 311              2       0.100000  ST000763
# 312              2     505.613333  ST000763
# 313              2     937.040000  ST000763
# 314              2       0.183333  ST000865
# 315              2       0.000000  ST000865
# 316              2       0.000000  ST000865
# 317              2       0.450000  ST000865
# 318              2      86.626667  ST000888
# 319              2       2.300000  ST000918

# %%
# save the df as a csv:
summary.to_csv('./onlysigfeat_withnumbers_30avg_auc_{}_sigfeat_summary_YES_bn_NO_log_NO_standscal_YES_ovo.csv'.format(model))
# save the df as a pickle
summary.to_pickle('./onlysigfeat_withnumbers_30avg_auc_{}_sigfeat_df_YES_bn_NO_log_NO_standscal_YES_ovo.pkl'.format(model))
# save dataset object:
pickle.dump(datasets, open('./onlysigfeat_withnumbers_30avg_{}_YES_bn_ds_models_and_sigfeat_NO_log_NO_standscal_YES_ovo.pkl'.format(model), 'wb'))

# %%
# map the extra metadata onto this data (column, mode, sample type)
# metadata = pd.read_csv('./ms_instrument_column_polarity_dataset_names.csv', sep='\t')
metadata = pd.read_csv('./ms_instrument_column_polarity_dataset_names.csv', sep='\t').set_index('Accession')
summary_w_metadata = summary.merge(metadata, on='analysis')
summary_w_metadata = summary_w_metadata.replace(np.nan,'unknown')
summary_w_metadata.to_csv('./1onlysigfeat_withnumbers_30avg_{}_auc_sigfeat_summary_YES_bn_NO_log_NO_standscal_YES_ovo_YES_meta.csv'.format(model))

# %%
param_grid = {'n_components': [2,3,4,5]}
clf = GridSearchCV(PLSRegression(), param_grid, cv=3, n_jobs=-1)
print(clf.get_params()['estimator'].n_components)
# Out:
# 2
